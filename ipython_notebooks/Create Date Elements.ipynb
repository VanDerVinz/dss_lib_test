# %%
# %matplotlib

# %%
import dataiku
from dataiku import pandasutils as pdu
import pandas as pd

from date_handling import DateTimeExtractor

# %%
# Example: load a DSS dataset as a Pandas dataframe
input_dataset = dataiku.Dataset("t_shirt_data_prepared")
input_df = input_dataset.get_dataframe()

# %%
df = pd.read_csv("./data/orders.csv")
extract = DateTimeExtractor(df, "order_date")
# extract and set date components 
extract.set_all()

df_with_date_components = extract.df
df_with_date_components.head()

# %%
1+1

# %%
class Project:
    
    run_result: dict = None
    def __init__(self):
        self.project = 'project'

class Parent:
    project: Project = Project()

# %%
from abc import ABC, abstractmethod

class Base(ABC):
    def __init__(self):
        print("Base initialized")
        self.value = 42

    @abstractmethod
    def run(self):
        pass

class Child(Base):
    def __init__(self):
        super().__init__()  # Important to call this!
        print("Child initialized")
    
    def run(self):
        pass

# %%
child = Child()

# %%
child.value
